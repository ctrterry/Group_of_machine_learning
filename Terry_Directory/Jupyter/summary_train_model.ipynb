# %% [markdown]
# ##  I can begin to train my model !!!! Finallllly

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/ready_to_process_v03.csv", sep = ',', header = 'infer')

# %%
df.head(5)
# Out:
#                              original_title  popularity  runtime  \
# 0                    Hot Tub Time Machine 2    6.575393     93.0
# 1  The Princess Diaries 2: Royal Engagement    8.248895    113.0
# 2                                  Whiplash   44.775274    105.0
# 3                            The Possession    7.286477     92.0
# 4                            The Possession    7.286477     92.0
#
#    averageRating  release_year  release_month  num_critic_for_reviews  \
# 0            5.0        2015.0            2.0                   107.0
# 1            5.9        2004.0            8.0                    77.0
# 2            8.5        2014.0           10.0                   535.0
# 3            5.9        2012.0            8.0                   264.0
# 4            5.9        2012.0            8.0                   264.0
#
#    director_facebook_likes  actor_1_facebook_likes  actor_2_facebook_likes  \
# ...

# %% [markdown]
# ![image](../Important_plot/feature_importance_updated.png)

# %% [markdown]
# ## The feature selective is based on the graphic "important score" > 0.02

# %% [markdown]
# ## Summary model as Kfolder, Random Forest vs MLP (ANN).

# %% [markdown]
# ## ANN Abalation Study Report

# %% [markdown]
# ![image.png](attachment:512b5aa8-d02e-4d18-9c9b-a009d7be3244.png)

# %% [markdown]
# ## Random Forest Tree

# %% [markdown]
# - Random Forest Evaluation Report
# - Test set size: 1061
# - MSE: 0.6186
# - RMSE: 0.7865
# - MAE: 0.5747
# - R²: 0.4589

# %% [markdown]
# ## KFolder split -> 5 with Random Forst Tree

# %% [markdown]
# K-fold Cross-validation Results
# =============================
#
# Number of folds: 5
# Total samples: 5305
#
# Features used:
# - popularity
# - runtime
# - release_year
# - release_month
# - num_critic_for_reviews
# - director_facebook_likes
# - actor_1_facebook_likes
# - actor_2_facebook_likes
# - actor_3_facebook_likes
# - num_user_for_reviews
# - movie_facebook_likes
# - budget_adjusted
# - Genre_first_values
#
# Fold Information:
#
# Fold 1:
#   Training set size: 4244
#   Validation set size: 1061
#   MSE: 0.6150
#   R²: 0.4620
#
# Fold 2:
#   Training set size: 4244
#   Validation set size: 1061
#   MSE: 0.6658
#   R²: 0.4464
#
# Fold 3:
#   Training set size: 4244
#   Validation set size: 1061
#   MSE: 0.6610
#   R²: 0.4211
#
# Fold 4:
#   Training set size: 4244
#   Validation set size: 1061
#   MSE: 0.7420
#   R²: 0.4014
#
# Fold 5:
#   Training set size: 4244
#   Validation set size: 1061
#   MSE: 0.7322
#   R²: 0.3968
#
# Overall Performance:
# Average MSE: 0.6832 ± 0.0476
# Average R²: 0.4256 ± 0.0253

# %% [markdown]
# ## conclusion:
#
# - While the ANN provides valuable insights into hyperparameter
# impacts. However the random forest tree-based methods demonstrate
# superior predictive power on tabular movie metadata.
# - Therefore, the Random Forrest Tree is the best model to predict "Rating" Based on the our data report
